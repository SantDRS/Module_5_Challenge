# %% [markdown]
# # Pymaceuticals Inc.
# ---
#
# ### Analysis
#
# - The Capomulin treatment showed a 5 point = 1/8th change in tumor volume in Mouse ID b742 over the studied 45 days.
# - The regression equation of y=0.95x + 21.55 helps us understand that the higher the weight of the mouse, the larger the tumor volume. The data fit the regression line by .709 giving us significant proportion.
# - Based on the boxplots Capomulin & Ramicane seem to be the most effective regimens, but they also had the most mice participate. I would question then if there was some sort of preference to these two regiments.
# - We could also see that there was an almost even mix of male vs female mice at 51% to 49% resepectively.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
from scipy.stats import linregress

# %%
# Study data files
mouse_metadata_path = "data/Mouse_metadata.csv"
study_results_path = "data/Study_results.csv"

# %%
# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata_path)
study_results = pd.read_csv(study_results_path)

# %%
# Review mouse_metadata
mouse_metadata.head()
# Out:
#   Mouse ID Drug Regimen     Sex  Age_months  Weight (g)
# 0     k403     Ramicane    Male          21          16
# 1     s185    Capomulin  Female           3          17
# 2     x401    Capomulin  Female          16          15
# 3     m601    Capomulin    Male          22          17
# 4     g791     Ramicane    Male          11          16

# %%
# Review study_results
study_results.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites
# 0     b128          0                45.0                 0
# 1     f932          0                45.0                 0
# 2     g107          0                45.0                 0
# 3     a457          0                45.0                 0
# 4     c819          0                45.0                 0

# %%
# Combine the data into a single dataset
combined_df = pd.merge(study_results, mouse_metadata, on = "Mouse ID")

# Display the data table for preview
combined_df.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128          0           45.000000                 0    Capomulin
# 1     b128          5           45.651331                 0    Capomulin
# 2     b128         10           43.270852                 0    Capomulin
# 3     b128         15           43.784893                 0    Capomulin
# 4     b128         20           42.731552                 0    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1  Female           9          22
# 2  Female           9          22
# 3  Female           9          22
# 4  Female           9          22

# %%
# Checking the number of mice.
mice = len(combined_df[ "Mouse ID"].unique())
mice
# Out:
# 249

# %%
# Getting the duplicate mice by ID number that shows up for Mouse ID and Timepoint. 
duplicate_mice_id = combined_df.loc[combined_df.duplicated(subset = ["Mouse ID", "Timepoint"]), "Mouse ID"].unique()
duplicate_mice_id
# Out:
# array(['g989'], dtype=object)

# %%
# Optional: Get all the data for the duplicate mouse ID. 
duplicate_mice_g989 = combined_df.loc[combined_df["Mouse ID"] == "g989", :]
duplicate_mice_g989
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 860     g989          0           45.000000                 0     Propriva
# 861     g989          0           45.000000                 0     Propriva
# 862     g989          5           48.786801                 0     Propriva
# 863     g989          5           47.570392                 0     Propriva
# 864     g989         10           51.745156                 0     Propriva
# 865     g989         10           49.880528                 0     Propriva
# 866     g989         15           51.325852                 1     Propriva
# 867     g989         15           53.442020                 0     Propriva
# 868     g989         20           55.326122                 1     Propriva
# 869     g989         20           54.657650                 1     Propriva
# 870     g989         25           56.045564                 1     Propriva
# 871     g989         30           59.082294                 1     Propriva
# 872     g989         35           62.570880                 2     Propriva
#
#         Sex  Age_months  Weight (g)
# 860  Female          21          26
# 861  Female          21          26
# 862  Female          21          26
# 863  Female          21          26
# 864  Female          21          26
# 865  Female          21          26
# 866  Female          21          26
# 867  Female          21          26
# 868  Female          21          26
# 869  Female          21          26
# 870  Female          21          26
# 871  Female          21          26
# 872  Female          21          26

# %%
# Create a clean DataFrame by dropping the duplicate mouse by its ID.
clean_df = combined_df[combined_df["Mouse ID"].isin(duplicate_mice_id) == False]

# %%
# Checking the number of mice in the clean DataFrame.
mice = len(clean_df[ "Mouse ID"].unique())
mice
# Out:
# 248

# %% [markdown]
# ## Summary Statistics

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
# Use groupby and summary statistical methods to calculate the following properties of each drug regimen: 
# mean, median, variance, standard deviation, and SEM of the tumor volume. 

mean = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).mean()
median = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).median()
variance = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).var()
standard_deviation = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).std()
SEM = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).sem()

# Assemble the resulting series into a single summary DataFrame.
summary_stats = pd.DataFrame({"Mean Tumor Volume" : mean,
                             "Median Tumor Volume" : median,
                             "Variance Tumor Volume" : variance,
                             "Standard Deviation Tumor Volume" : standard_deviation,
                             "Standard Error Tumor Volume" : SEM
                             }
                            )
# Display the summary
summary_stats
# Out:
#               Mean Tumor Volume  Median Tumor Volume  Variance Tumor Volume  \
# Drug Regimen
# Capomulin             40.675741            41.557809              24.947764
# Ceftamin              52.591172            51.776157              39.290177
# Infubinol             52.884795            51.820584              43.128684
# Ketapril              55.235638            53.698743              68.553577
# Naftisol              54.331565            52.509285              66.173479
# Placebo               54.033581            52.288934              61.168083
# Propriva              52.320930            50.446266              43.852013
# Ramicane              40.216745            40.673236              23.486704
# Stelasyn              54.233149            52.431737              59.450562
# Zoniferol             53.236507            51.818479              48.533355
#
#               Standard Deviation Tumor Volume  Standard Error Tumor Volume
# Drug Regimen
# Capomulin                            4.994774                     0.329346
# Ceftamin                             6.268188                     0.469821
# Infubinol                            6.567243                     0.492236
# Ketapril                             8.279709                     0.603860
# Naftisol                             8.134708                     0.596466
# Placebo                              7.821003                     0.581331
# Propriva                             6.622085                     0.544332
# Ramicane                             4.846308                     0.320955
# Stelasyn                             7.710419                     0.573111
# Zoniferol                            6.966589                     0.516398

# %%
clean_df
# Out:
#      Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0        b128          0           45.000000                 0    Capomulin
# 1        b128          5           45.651331                 0    Capomulin
# 2        b128         10           43.270852                 0    Capomulin
# 3        b128         15           43.784893                 0    Capomulin
# 4        b128         20           42.731552                 0    Capomulin
# ...       ...        ...                 ...               ...          ...
# 1888     m601         25           33.118756                 1    Capomulin
# 1889     m601         30           31.758275                 1    Capomulin
# 1890     m601         35           30.834357                 1    Capomulin
# 1891     m601         40           31.378045                 1    Capomulin
# 1892     m601         45           28.430964                 1    Capomulin
#
#          Sex  Age_months  Weight (g)
# 0     Female           9          22
# 1     Female           9          22
# 2     Female           9          22
# 3     Female           9          22
# 4     Female           9          22
# ...      ...         ...         ...
# 1888    Male          22          17
# 1889    Male          22          17
# 1890    Male          22          17
# 1891    Male          22          17
# 1892    Male          22          17
#
# [1880 rows x 8 columns]

# %%
mean = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).mean()
median = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).median()
variance = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).var()
standard_deviation = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).std()
SEM = clean_df["Tumor Volume (mm3)"].groupby(clean_df["Drug Regimen"]).sem()

# %%
# Generate a summary statistics table of mean, median, variance, standard deviation, 
# and SEM of the tumor volume for each regimen
# Using the aggregation method, produce the same summary statistics in a single line.

regimens_summary = clean_df.groupby(["Drug Regimen"])[["Tumor Volume (mm3)"]]
regimens_summary = regimens_summary.agg(["mean", "median"])
regimens_summary.head()
# Out:
#              Tumor Volume (mm3)
#                            mean     median
# Drug Regimen
# Capomulin             40.675741  41.557809
# Ceftamin              52.591172  51.776157
# Infubinol             52.884795  51.820584
# Ketapril              55.235638  53.698743
# Naftisol              54.331565  52.509285

# %% [markdown]
# ## Bar and Pie Charts

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# First create a group series using the "Drug Regimen"
mice_count = clean_df["Drug Regimen"].value_counts()

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using Pandas.

# Set labels
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.title("Number of Mice x Drug Regimen")

# Create Plot
regimen_per_mice = mice_count.plot.bar(color = "b")

# %%
# Generate a bar plot showing the total number of timepoints for all mice tested for each drug regimen using pyplot.

x_axis = mice_count.index.values
y_axis = mice_count.values

# Set labels
plt.xlabel("Drug Regimen")
plt.ylabel("Number of Mice Tested")
plt.title("Number of Mice x Drug Regimen")
plt.xticks(rotation = "vertical")

# Create plot 
plt.bar(x_axis, y_axis, color = "b", alpha = 1, align = "center")

# Display plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using Pandas

# Build data
gender_df = clean_df["Sex"].value_counts()

# Set labels
plt.title("Female vs. Male Mice")

# Create plot
gender_df.plot.pie(autopct = "%1.1f%%")

# Show plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot

# Set values
labels = ["Male", "Female"]
sizes = [gender_df["Male"], gender_df["Female"]]

# Set colors
colors = ["blue", "red"]

# Set labels
plt.ylabel("Sex")
#plt.title("Male vs. Female Mice")

explode = (.05,0)

# Create plot
plt.pie(sizes, explode = explode, labels = labels, colors = colors, autopct = "%1.1f%%", shadow = True, startangle = 0)

#Display plot
plt.show()

# %% [markdown]
# ## Quartiles, Outliers and Boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the treatment regimens:  
# Capomulin, Ramicane, Infubinol, and Ceftamin

Capomulin_df = clean_df.loc[clean_df["Drug Regimen"] == "Capomulin", :]
Ramicane_df = clean_df.loc[clean_df["Drug Regimen"] == "Ramicane", :]
Infubinol_df = clean_df.loc[clean_df["Drug Regimen"] == "Infubinol", :]
Ceftamin_df = clean_df.loc[clean_df["Drug Regimen"] == "Ceftamin", :]

# %%
# Start by getting the last (greatest) timepoint for each mouse

Capomulin_last = Capomulin_df.groupby("Mouse ID").max()["Timepoint"]
Capomulin_vol = pd.DataFrame(Capomulin_last)
Capomulin_merge = pd.merge(Capomulin_vol, clean_df, on = ("Mouse ID", "Timepoint"), how = "left")
Capomulin_merge.head()
# Out:
#   Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 0     b128         45           38.982878                 2    Capomulin
# 1     b742         45           38.939633                 0    Capomulin
# 2     f966         20           30.485985                 0    Capomulin
# 3     g288         45           37.074024                 1    Capomulin
# 4     g316         45           40.159220                 2    Capomulin
#
#       Sex  Age_months  Weight (g)
# 0  Female           9          22
# 1    Male           7          21
# 2    Male          16          17
# 3    Male           3          19
# 4  Female          22          22

# %%
Capomulin_tumors = Capomulin_merge["Tumor Volume (mm3)"]

quartiles = Capomulin_tumors.quantile([.25,.5,.75])
lowerq = quartiles.loc[0.25]
upperq = quartiles.loc[0.75]
iqr = upperq - lowerq

print(f"The lower quartile of Regimen is: {lowerq}")
print(f"The upper quartile of Regimen is: {upperq}")
print(f"The interquartile of Regimen is: {iqr}")
print(f"The the median of Regimen is: {quartiles.loc[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = lowerq + (1.5*iqr)

print(f"This is our lower-bound for outliers {lower_bound}.")
print(f"This is our upper-bound for outliers {upper_bound}.")
# Out:
# The lower quartile of treatment is: 32.37735684
# The upper quartile of treatment is: 40.1592203
# The interquartile of treatment is: 7.781863460000004
# The the median of temperatures is: 38.1251644
# This is our lower-bound for outliers 20.70456164999999.
# This is our upper-bound for outliers 44.05015203000001.

# %%
Ramicane_last = Ramicane_df.groupby("Mouse ID").max()["Timepoint"]
Ramicane_vol = pd.DataFrame(Ramicane_last)
Ramicane_merge = pd.merge(Ramicane_vol, clean_df, on = ("Mouse ID", "Timepoint"), how = "left")
Ramicane_merge.head()
Ramicane_tumors = Ramicane_merge["Tumor Volume (mm3)"]

quartiles = Ramicane_tumors.quantile([.25,.5,.75])
lowerq = quartiles.loc[0.25]
upperq = quartiles.loc[0.75]
iqr = upperq - lowerq

print(f"The lower quartile of Regimen is: {lowerq}")
print(f"The upper quartile of Regimen is: {upperq}")
print(f"The interquartile of Regimen is: {iqr}")
print(f"The the median of Regimen is: {quartiles.loc[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = lowerq + (1.5*iqr)

print(f"This is our lower-bound for outliers {lower_bound}.")
print(f"This is our upper-bound for outliers {upper_bound}.")
# Out:
# The lower quartile of treatment is: 31.56046955
# The upper quartile of treatment is: 40.65900627
# The interquartile of treatment is: 9.098536719999998
# The the median of temperatures is: 36.56165229
# This is our lower-bound for outliers 17.912664470000003.
# This is our upper-bound for outliers 45.20827463.

# %%
Infubinol_last = Infubinol_df.groupby("Mouse ID").max()["Timepoint"]
Infubinol_vol = pd.DataFrame(Infubinol_last)
Infubinol_merge = pd.merge(Infubinol_vol, clean_df, on = ("Mouse ID", "Timepoint"), how = "left")
Infubinol_merge.head()
Infubinol_tumors = Infubinol_merge["Tumor Volume (mm3)"]

quartiles = Infubinol_tumors.quantile([.25,.5,.75])
lowerq = quartiles.loc[0.25]
upperq = quartiles.loc[0.75]
iqr = upperq - lowerq

print(f"The lower quartile of Regimen is: {lowerq}")
print(f"The upper quartile of Regimen is: {upperq}")
print(f"The interquartile of Regimen is: {iqr}")
print(f"The the median of Regimen is: {quartiles.loc[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = lowerq + (1.5*iqr)

print(f"This is our lower-bound for outliers {lower_bound}.")
print(f"This is our upper-bound for outliers {upper_bound}.")
# Out:
# The lower quartile of treatment is: 54.04860769
# The upper quartile of treatment is: 65.52574285
# The interquartile of treatment is: 11.477135160000003
# The the median of temperatures is: 60.16518046
# This is our lower-bound for outliers 36.83290494999999.
# This is our upper-bound for outliers 71.26431043.

# %%
Ceftamin_last = Ceftamin_df.groupby("Mouse ID").max()["Timepoint"]
Ceftamin_vol = pd.DataFrame(Ceftamin_last)
Ceftamin_merge = pd.merge(Ceftamin_vol, clean_df, on = ("Mouse ID", "Timepoint"), how = "left")
Ceftamin_merge.head()
Ceftamin_tumors = Ceftamin_merge["Tumor Volume (mm3)"]

quartiles = Ceftamin_tumors.quantile([.25,.5,.75])
lowerq = quartiles.loc[0.25]
upperq = quartiles.loc[0.75]
iqr = upperq - lowerq

print(f"The lower quartile of Regimen is: {lowerq}")
print(f"The upper quartile of Regimen is: {upperq}")
print(f"The interquartile of Regimen is: {iqr}")
print(f"The the median of Regimen is: {quartiles.loc[0.5]} ")

lower_bound = lowerq - (1.5*iqr)
upper_bound = lowerq + (1.5*iqr)

print(f"This is our lower-bound for outliers {lower_bound}.")
print(f"This is our upper-bound for outliers {upper_bound}.")
# Out:
# The lower quartile of treatment is: 48.72207785
# The upper quartile of treatment is: 64.29983003
# The interquartile of treatment is: 15.577752179999997
# The the median of temperatures is: 59.85195552
# This is our lower-bound for outliers 25.355449580000002.
# This is our upper-bound for outliers 72.08870612.

# %%
# Generate a box plot that shows the distrubution of the tumor volume for each treatment group.
Regimen_plot = [Capomulin_tumors, Ramicane_tumors, Infubinol_tumors, Ceftamin_tumors]
Regimen_names = ["Campomulin", "Ramicane", "Infubinol", "Ceftamin"]

fig1, axl = plt.subplots()
axl.set_title("Tumor Volume at Selected Mouse")
axl.set_xlabel("Drug Regimen")
axl.set_ylabel("Final Tumor Volume (mm3)")
axl.boxplot(Regimen_plot, labels = Regimen_names, widths = 0.5, vert = True)
plt.show()

# %%
# Merge this group df with the original DataFrame to get the tumor volume at the last timepoint
Regimen_names = ["Campomulin", "Ramicane", "Infubinol", "Ceftamin"]
Regimen = combined_df[combined_df["Drug Regimen"].isin(Regimen_names)]
Regimen.head()
# Out:
#     Mouse ID  Timepoint  Tumor Volume (mm3)  Metastatic Sites Drug Regimen  \
# 213     c326          0           45.000000                 0    Infubinol
# 214     c326          5           36.321346                 0    Infubinol
# 215     c139          0           45.000000                 0    Infubinol
# 216     c139          5           48.753112                 0    Infubinol
# 217     c139         10           49.992954                 0    Infubinol
#
#         Sex  Age_months  Weight (g)
# 213  Female          18          25
# 214  Female          18          25
# 215    Male          11          28
# 216    Male          11          28
# 217    Male          11          28

# %%
# Attempt at for loop, but didn't get it to work...

# Put treatments into a list for for loop (and later for plot labels)
Greatest_timepoint = Regimen.groupby(["Drug Regimen", "Mouse ID"]).agg(tumor_size=("Tumor Volume (mm3)", lambda x: x.iloc[-1]))

Greatest_timepoint = Greatest_timepoint.stack(level = 0).unstack(level = 0)

for Regimen in Regimen_names:
    print(Regimen)
    
treatment = 0

for x in Regimen_names:
    quartiles = Greatest_timepoint.quantile([.25,.5,.75])
    lowerq = quartiles[0.25]
    upperq = quartiles[0.75]
    iqr = upperq - lowerq
    lower_bound = lowerq - (1.5*iqr)
    upper_bound = lowerq + (1.5*iqr)
    
    if treatment ==0:
        print(f"The lower quartile of treatment is: {lowerq}")
        print(f"The upper quartile of treatment is: {upperq}")
        print(f"The interquartile of treatment is: {iqr}")
        print(f"The the median of temperatures is: {quartiles.loc[0.5]} ")
        print(f"This is our lower-bound for outliers {lower_bound}.")
        print(f"This is our upper-bound for outliers {upper_bound}.")
        treatment +=1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/lt/3y0bt5w1291dpn5_jxn56_rw0000gn/T/ipykernel_1494/3504742704.py in <module>
#       1 # Put treatments into a list for for loop (and later for plot labels)
# ----> 2 Greatest_timepoint = Regimen.groupby(["Drug Regimen", "Mouse ID"]).agg(tumor_size=("Tumor Volume (mm3)", lambda x: x.iloc[-1]))
#       3
#       4 Greatest_timepoint = Greatest_timepoint.stack(level = 0).unstack(level = 0)
#       5
#
# AttributeError: 'str' object has no attribute 'groupby'

# %% [markdown]
# ## Line and Scatter Plots

# %%
# Generate a line plot of tumor volume vs. time point for a mouse treated with Capomulin
Capomulin_mouse = Capomulin_df.loc[Capomulin_df["Mouse ID"] == "b742", :]

x_axis = Capomulin_mouse["Timepoint"]
y_axis = Capomulin_mouse["Tumor Volume (mm3)"]
Capomulin_mouse.head()

fig1, ax1 = plt.subplots()
plt.xlabel("Timepoint (Days)")
plt.ylabel("Tumor Volume (mm3)")
plt.title("Capomulin Treatment on Mouse ID b742")
plt.plot(x_axis, y_axis, color = "b")

plt.show()

# %%
# Generate a scatter plot of average tumor volume vs. mouse weight for the Capomulin regimen
Capomulin_avg_vol = Capomulin_df.groupby(["Mouse ID"]).mean()

x_axis = Capomulin_avg_vol["Weight (g)"]
y_axis = Capomulin_avg_vol["Tumor Volume (mm3)"]

plt.title("Avg Tumor Volume vs Mouse Weight")
plt.xlabel("Weight (g)")
plt.ylabel("Avg Tumor Volume (3mm)")
plt.scatter(x_axis, y_axis, color = "b" )

plt.show()

# %% [markdown]
# ## Correlation and Regression

# %%
# Calculate the correlation coefficient and linear regression model 
# for mouse weight and average tumor volume for the Capomulin regimen

Capomulin_correlation = st.pearsonr(Capomulin_avg_vol["Weight (g)"], Capomulin_avg_vol["Tumor Volume (mm3)"])
print(f"The correlation between mouse weight and the average tumor volume is {round(Capomulin_correlation[0],2)}")
# Out:
# The correlation between mouse weight and the average tumor volume is 0.84

# %%
# Plot the regression

# Scatter Data
Capomulin_avg_vol = Capomulin_df.groupby(["Mouse ID"]).mean()
x_axis = Capomulin_avg_vol["Weight (g)"]
y_axis = Capomulin_avg_vol["Tumor Volume (mm3)"]

# Linear Regression Data
(slope, intercept, rvalue, pvalue, stderr) = linregress(Capomulin_avg_vol["Weight (g)"], Capomulin_avg_vol["Tumor Volume (mm3)"])
regress_values = Capomulin_avg_vol["Weight (g)"] * slope + intercept
line_eq = f"y = {round(slope, 2)}x + {round(intercept, 2)}"

# Add labels
plt.title("Capomulin: Mouse Wt vs Tumor Avg Vol")
plt.xlabel("Weight (g)")
plt.ylabel("Avg Tumor Volume (3mm)")

# Plot
plt.scatter(x_axis, y_axis, color = "b" )
plt.plot(Capomulin_avg_vol["Weight (g)"], regress_values, color = "r")
plt.annotate(line_eq, (22,36), fontsize = 10)
plt.show()
print(f"The r-squared value is: {round(rvalue**2,3)}")
# Out:
# The r-squared value is: 0.709
